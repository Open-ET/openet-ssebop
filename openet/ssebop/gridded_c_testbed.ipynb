# %%
import sys
# sys.path
import ee
import pprint
from IPython.display import Image
from image import Image as local_model

# %%
try:
    ee.Initialize(use_cloud_api=True)
    print('worked')
except ee.EEException:
    ee.Authenticate()
    ee.Initialize(use_cloud_api=True)
# Out:
# worked

# %%
ndvi_palette = ['#EFE7E1', '#003300']
et_palette = [
    'DEC29B', 'E6CDA1', 'EDD9A6', 'F5E4A9', 'FFF4AD', 'C3E683', '6BCC5C', 
    '3BB369', '20998F', '1C8691', '16678A', '114982', '0B2C7A']

image_size = 768

# %%
# landsat_img = ee.Image('LANDSAT/LC08/C01/T1_TOA/LC08_043035_20190715')
# # landsat_img = ee.Image('LANDSAT/LC08/C01/T1_SR/LC08_044033_20170801')

# landsat_crs = landsat_img.select('B3').projection().getInfo()['crs']
# landsat_region = landsat_img.geometry().bounds(1, 'EPSG:4326')
# landsat_dt = ee.Date(landsat_img.get('system:time_start'))
# # print(landsat_img.get('system:time_start').getInfo())

landsat_img = ee.Image('LANDSAT/LC08/C01/T1_TOA/LC08_044033_20170716')
# landsat_img = ee.Image('LANDSAT/LC08/C01/T1_SR/LC08_044033_20170801')

landsat_crs = landsat_img.select('B3').projection().getInfo()['crs']
landsat_region = landsat_img.geometry().bounds(1, 'EPSG:4326')
landsat_dt = ee.Date(landsat_img.get('system:time_start'))
# print(landsat_img.get('system:time_start').getInfo())

# %%
image_url = landsat_img.select([3, 2, 1])\
    .getThumbURL({'min': 0.0, 'max': 0.3, 
                  'region': landsat_region, 'dimensions': image_size})
Image(image_url, embed=True, format='png')

# %%
# model_obj = local_model(
#     landsat_img, 
#     et_reference_source='IDAHO_EPSCOR/GRIDMET', 
#     et_reference_band='etr', 
#     et_reference_factor=0.85,
#     et_reference_resample='nearest',)

# Build the SSEBop object from the Landsat image
model_obj = local_model.from_landsat_c1_toa(
    landsat_img,
    et_reference_source='IDAHO_EPSCOR/GRIDMET', 
    et_reference_band='etr', 
    et_reference_factor=0.85,
    et_reference_resample='nearest',
)
# Out:
# gridded-C branch!
# Hello SSEBop! This is the gridded-c Branch of this model!

# %%
print(model_obj)


# image_url = model_obj.ndvi\
#     .getThumbURL({'min': -0.1, 'max': 0.9, 'palette': ndvi_palette, 
#                   'region': landsat_region, 'dimensions': image_size})
# Image(image_url, embed=True, format='png')
# Out:
# <image.Image object at 0x000001F14619F730>

# %%
print(model_obj.et_reference_source)
# Out:
# IDAHO_EPSCOR/GRIDMET

# %%
image_url = model_obj.ndvi\
    .getThumbURL({'min': -0.1, 'max': 0.9, 'palette': ndvi_palette, 
                  'region': landsat_region, 'dimensions': image_size})
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\eeapi\lib\site-packages\ee\data.py in _execute_cloud_call(call, num_retries)
#     337   try:
# --> 338     return call.execute(num_retries=num_retries)
#     339   except apiclient.errors.HttpError as e:
#
# C:\ProgramData\Anaconda3\envs\eeapi\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#
# C:\ProgramData\Anaconda3\envs\eeapi\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     897         if resp.status >= 300:
# --> 898             raise HttpError(resp, content, uri=self.uri)
#     899         return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails?fields=name&alt=json returned "Image.select: Pattern 'lst' did not match any bands.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# <ipython-input-49-dda72ca35648> in <module>
# ----> 1 image_url = model_obj.ndvi\
#       2     .getThumbURL({'min': -0.1, 'max': 0.9, 'palette': ndvi_palette,
#       3                   'region': landsat_region, 'dimensions': image_size})
#
# C:\ProgramData\Anaconda3\envs\eeapi\lib\site-packages\ee\image.py in getThumbURL(self, params)
#     490     # behaviour.
#     491     if data._use_cloud_api:  # pylint: disable=protected-access
# --> 492       return data.makeThumbUrl(self.getThumbId(params))
#     493     image, params = self._apply_visualization(params)
#     494     params['image'] = image
#
# C:\ProgramData\Anaconda3\envs\eeapi\lib\site-packages\ee\image.py in getThumbId(self, params)
#     462     image, params = image._apply_visualization(params)  # pylint: disable=protected-access
#     463     params['image'] = image
# --> 464     return data.getThumbId(params)
#     465
#     466   def getThumbURL(self, params=None):
#
# C:\ProgramData\Anaconda3\envs\eeapi\lib\site-packages\ee\data.py in getThumbId(params, thumbType)
#     827       request['bandIds'] = _cloud_api_utils.convert_to_band_list(
#     828           params.get('bands'))
# --> 829       result = _execute_cloud_call(
#     830           _cloud_api_resource.projects().thumbnails().create(
#     831               parent=_get_projects_path(),
#
# C:\ProgramData\Anaconda3\envs\eeapi\lib\site-packages\ee\data.py in _execute_cloud_call(call, num_retries)
#     338     return call.execute(num_retries=num_retries)
#     339   except apiclient.errors.HttpError as e:
# --> 340     raise _translate_cloud_exception(e)
#     341
#     342
#
# EEException: Image.select: Pattern 'lst' did not match any bands.
